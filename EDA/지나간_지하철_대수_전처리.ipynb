# %% [markdown]
# ## 서울교통공사 지하철역 시간대별 지나간 지하철 대수 전처리
# - https://data.seoul.go.kr/dataList/OA-101/A/1/datasetView.do

# %% [markdown]
# ### 데이터 불러오기

# %%
import requests

# 실제 서비스 키
SERVICE_KEY = '6c41706a496e617931394343774c44'
# 전체 지하철 역 코드를 저장할 리스트 초기화
subway_codes = []

# 전체 지하철 역 코드 목록을 가져오기 위한 URL
station_list_url = f'http://openAPI.seoul.go.kr:8088/{SERVICE_KEY}/json/SearchInfoBySubwayNameService/1/1000/'

# API를 사용하여 전체 지하철 역 코드 목록을 가져오기
req = requests.get(station_list_url)
print(req)
print(req.text)
# Out:
# <Response [200]>
# {"SearchInfoBySubwayNameService":{"list_total_count":777,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"STATION_CD":"0244","STATION_NM":"용답","LINE_NUM":"02호선","FR_CODE":"211-1"},{"STATION_CD":"0245","STATION_NM":"신답","LINE_NUM":"02호선","FR_CODE":"211-2"},{"STATION_CD":"0250","STATION_NM":"용두","LINE_NUM":"02호선","FR_CODE":"211-3"},{"STATION_CD":"0336","STATION_NM":"학여울","LINE_NUM":"03호선","FR_CODE":"346"},{"STATION_CD":"0428","STATION_NM":"삼각지","LINE_NUM":"04호선","FR_CODE":"428"},{"STATION_CD":"0429","STATION_NM":"신용산","LINE_NUM":"04호선","FR_CODE":"429"},{"STATION_CD":"1008","STATION_NM":"이촌","LINE_NUM":"경의선","FR_CODE":"K111"},{"STATION_CD":"1014","STATION_NM":"청량리","LINE_NUM":"경의선","FR_CODE":"K117"},{"STATION_CD":"103C","STATION_NM":"대곡","LINE_NUM":"서해선","FR_CODE":"836"},{"STATION_CD":"104C","STATION_NM":"능곡","LINE_NUM":"서해선","FR_CODE":"837"},{"STATION_CD":"105C","STATION_NM":"곡산","LINE_NUM":"서해선","FR_CODE":"835"},{"STATION_CD":"106C","STATION_NM":"백마","LINE_NUM":"서해선","FR_CODE":"834"},{"STATION_CD":"107C","STATION_NM":"풍산","LINE_NUM":"서해선","FR_CODE":"833"},{"STATION_CD":"108C","STATION_NM":"일산","LINE_NUM":"서해선","FR_CODE":"832"},{"STATION_CD":"0412","STATION_NM":"창동","LINE_NUM":"04호선","FR_CODE":"412"},{"STATION_CD":"0417","STATION_NM":"길음","LINE_NUM":"04호선","FR_CODE":"417"},{"STATION_CD":"102C","STATION_NM":"왕십리","LINE_NUM":"수인분당선","FR_CODE":"K210"},{"STATION_CD":"1030","STATION_NM":"수서","LINE_NUM":"수인분당선","FR_CODE":"K221"},{"STATION_CD":"1217","STATION_NM":"양평","LINE_NUM":"경의선","FR_CODE":"K135"},{"STATION_CD":"1218","STATION_NM":"원덕","LINE_NUM":"경의선","FR_CODE":"K136"},{"STATION_CD":"1286","STATION_NM":"운천","LINE_NUM":"경의선","FR_CODE":"K336"},{"STATION_CD":"1407","STATION_NM":"온양온천","LINE_NUM":"01호선","FR_CODE":"P176"},{"STATION_CD":"1450","STATION_NM":"선바위","LINE_NUM":"04호선","FR_CODE":"435"},{"STATION_CD":"1452","STATION_NM":"대공원","LINE_NUM":"04호선","FR_CODE":"437"},{"STATION_CD":"1455","STATION_NM":"인덕원","LINE_NUM":"04호선","FR_CODE":"440"},{"STATION_CD":"1456","STATION_NM":"평촌","LINE_NUM":"04호선","FR_CODE":"441"},{"STATION_CD":"1504","STATION_NM":"경기광주","LINE_NUM":"경강선","FR_CODE":"K413"},{"STATION_CD":"3227","STATION_NM":"운연","LINE_NUM":"인천2호선","FR_CODE":"I227"},{"STATION_CD":"0310","STATION_NM":"구파발","LINE_NUM":"03호선","FR_CODE":"320"},{"STATION_CD":"0319","STATION_NM":"종로3가","LINE_NUM":"03호선","FR_CODE":"329"},{"STATION_CD":"0339","STATION_NM":"수서","LINE_NUM":"03호선","FR_CODE":"349"},{"STATION_CD":"0415","STATION_NM":"미아","LINE_NUM":"04호선","FR_CODE":"415"},{"STATION_CD":"0425","STATION_NM":"회현","LINE_NUM":"04호선","FR_CODE":"425"},{"STATION_CD":"100C","STATION_NM":"용산","LINE_NUM":"경의선","FR_CODE":"K110"},{"STATION_CD":"1013","STATION_NM":"왕십리","LINE_NUM":"경의선","FR_CODE":"K116"},{"STATION_CD":"1264","STATION_NM":"홍대입구","LINE_NUM":"경의선","FR_CODE":"K314"},{"STATION_CD":"1265","STATION_NM":"가좌","LINE_NUM":"경의선","FR_CODE":"K315"},{"STATION_CD":"1279","STATION_NM":"금릉","LINE_NUM":"경의선","FR_CODE":"K330"},{"STATION_CD":"1408","STATION_NM":"신창","LINE_NUM":"01호선","FR_CODE":"P177"},{"STATION_CD":"1458","STATION_NM":"금정","LINE_NUM":"04호선","FR_CODE":"443"},{"STATION_CD":"1502","STATION_NM":"이매","LINE_NUM":"경강선","FR_CODE":"K411"},{"STATION_CD":"0248","STATION_NM":"양천구청","LINE_NUM":"02호선","FR_CODE":"234-2"},{"STATION_CD":"0320","STATION_NM":"을지로3가","LINE_NUM":"03호선","FR_CODE":"330"},{"STATION_CD":"0327","STATION_NM":"신사","LINE_NUM":"03호선","FR_CODE":"337"},{"STATION_CD":"1005","STATION_NM":"대방","LINE_NUM":"01호선","FR_CODE":"137"},{"STATION_CD":"1031","STATION_NM":"복정","LINE_NUM":"수인분당선","FR_CODE":"K222"},{"STATION_CD":"1204","STATION_NM":"양원","LINE_NUM":"경의선","FR_CODE":"K122"},{"STATION_CD":"1510","STATION_NM":"세종대왕릉","LINE_NUM":"경강선","FR_CODE":"K419"},{"STATION_CD":"1703","STATION_NM":"금천구청","LINE_NUM":"01호선","FR_CODE":"P144"},{"STATION_CD":"1720","STATION_NM":"진위","LINE_NUM":"01호선","FR_CODE":"P161"},{"STATION_CD":"1834","STATION_NM":"안산","LINE_NUM":"수인분당선","FR_CODE":"K255"},{"STATION_CD":"1864","STATION_NM":"신갈","LINE_NUM":"수인분당선","FR_CODE ...

# %%
if req.status_code == 200:
    data = req.json()
    if 'SearchInfoBySubwayNameService' in data:
        for item in data['SearchInfoBySubwayNameService']['row']:
            subway_code = item['STATION_CD']  # 역 코드 가져오기
            subway_codes.append(subway_code)
    else:
        print("데이터에 'SearchInfoBySubwayNameService'가 없습니다.")
else:
    print("역 코드 목록을 가져오는 데 실패했습니다.")

# %%
# 각 지하철 역 코드에 대한 데이터 수집
all_data = []  # 모든 역의 데이터를 저장할 리스트 초기화

# 모든 요일과 상하행에 대한 조합에 대해 데이터 수집
for subway_code in subway_codes:
    for week_tag in ['1', '2', '3']:  # 모든 요일에 대한 조합
        for inout_tag in ['1', '2']:  # 상하행에 대한 조합
            url = f'http://openAPI.seoul.go.kr:8088/{SERVICE_KEY}/json/SearchSTNTimeTableByIDService/1/1000/{subway_code}/{week_tag}/{inout_tag}/'
            req = requests.get(url)

            if req.status_code == 200:
                data = req.json()
                all_data.append(data)  # 각 역의 데이터를 all_data 리스트에 추가
            else:
                print(f"역 코드 {subway_code}, 요일 {week_tag}, 상하행 {inout_tag}에 대한 데이터를 가져오는 데 실패했습니다.")

# all_data 리스트에는 각 역의 데이터가 저장되어 있습니다.

# %%
print(subway_codes)
# Out:
# ['0244', '0245', '0250', '0336', '0428', '0429', '1008', '1014', '103C', '104C', '105C', '106C', '107C', '108C', '0412', '0417', '102C', '1030', '1217', '1218', '1286', '1407', '1450', '1452', '1455', '1456', '1504', '3227', '0310', '0319', '0339', '0415', '0425', '100C', '1013', '1264', '1265', '1279', '1408', '1458', '1502', '0248', '0320', '0327', '1005', '1031', '1204', '1510', '1703', '1720', '1834', '1864', '1875', '3753', '4306', '0216', '0249', '0311', '0315', '0323', '0328', '0337', '0421', '1319', '1835', '1856', '1878', '1882', '3117', '3135', '3223', '3224', '3225', '3226', '0233', '0237', '0405', '0430', '1015', '1032', '1208', '1219', '1402', '1885', '1886', '1901', '1981', '2620', '2640', '2724', '2816', '2817', '0338', '0416', '0427', '1201', '1266', '1268', '1804', '1953', '1954', '2530', '2535', '2557', '2558', '2815', '3754', '3755', '3756', '3757', '3758', '3759', '0316', '0329', '0334', '0341', '1009', '1203', '1214', '1404', '1812', '1854', '1866', '1870', '1871', '1873', '1880', '1884', '1890', '3760', '3761', '0217', '0317', '0324', '0330', '0332', '0335', '1010', '1021', '1814', '1816', '1857', '1858', '1859', '1860', '1861', '1862', '1863', '1877', '3762', '0218', '0325', '0331', '1026', '1800', '1803', '1805', '1813', '1817', '1821', '1845', '1849', '1850', '1851', '1852', '1853', '1855', '3763', '0219', '0318', '1027', '1269', '1275', '1725', '1726', '1728', '1751', '1752', '1753', '1754', '1755', '1756', '1757', '1763', '1833', '1836', '4101', '4104', '0406', '1276', '1277', '1280', '1308', '1310', '1311', '1316', '1318', '1320', '1322', '1328', '1712', '1713', '1714', '1715', '1718', '1721', '1722', '1724', '4105', '0314', '0321', '1220', '1251', '1261', '1262', '1272', '1278', '1283', '1305', '1306', '1312', '1314', '1324', '1325', '1327', '1401', '1823', '4102', '4106', '0243', '0309', '0322', '0326', '0333', '0414', '0426', '0432', '1205', '1206', '1207', '1210', '1211', '1212', '1213', '1215', '1216', '1284', '4107', '0246', '0431', '0433', '0434', '1004', '1006', '1011', '1012', '1016', '1017', '1018', '1019', '1020', '1022', '1023', '1025', '1028', '0238', '0239', '0240', '0241', '0242', '0247', '0312', '0313', '0342', '0408', '0409', '0410', '0418', '0419', '0422', '1511', '0220', '0221', '0222', '0223', '0224', '0225', '0226', '0227', '0228', '0229', '0230', '0231', '0232', '0234', '0235', '0236', '0203', '0204', '0205', '0206', '0207', '0208', '0209', '0210', '0211', '0212', '0213', '0214', '0215', '0420', '1007', '1701', '4108', '0340', '0411', '0423', '1003', '1252', '1270', '1282', '1285', '1317', '1323', '1405', '1451', '1506', '4109', '4110', '4111', '4112', '4113', '4114', '4115', '4116', '4117', '4118', '4123', '4129', '0413', '0424', '1002', '1024', '1309', '1321', '1508', '1719', '1822', '1868', '1980', '2513', '2517', '4119', '4203', '4210', '4211', '4212', '4213', '4215', '4217', '4502', '4503', '4508', '4509', '101C', '1202', '1209', '1263', '1274', '1307', '1315', '1503', '1705', '1806', '1808', '1809', '1811', '1815', '1879', '1910', '2515', '2526', '4808', '4809', '4813', '4814', '1267', '1273', '1313', '1403', '1453', '1457', '1505', '1507', '1729', '1758', '1955', '1957', '1958', '2519', '4304', '4501', '4504', '4505', '4506', '4810', '4811', '4812', '1329', '1454', '1501', '1509', '1710', '1716', '1727', '1749', '1759', '1762', '1810', '2549', '2553', '4815', '4920', '4921', '4922', '4923', '4924', '4925', '4926', '4927', '1717', '1723', '1760', '1801', '1807', '1830', '1831', '1876', '1889', '2538', '2562', '2625', '2626', '2630', '4928', '4929', '1702', '1704', '1706', '1707', '1708', '1709', '1711', '1750', '1761', '1802', '1832', '1846', '1847', '1848', '1865', '1867', '1869', '1872', '1874', '1881', '1888', '1907', '1908', '1914', '2528', '2531', '2532', '2533', '2534', '2612', '2623', '2643', '2644', '2645', '2647', '2819', '1883', '1891', '1902', '1903', '1904', '1905', '1906', '1909', '1911', '1912', '1913', '1915', '1916', '1948', '1950', '1951', '1952', '1956', ...

# %% [markdown]
# ### 데이터 프레임 만들기

# %%
import pandas as pd

# all_data 리스트에 있는 모든 데이터를 하나의 데이터프레임으로 합치기
all_data_frames = []
for data in all_data:
    if 'SearchSTNTimeTableByIDService' in data:
        df = pd.DataFrame(data['SearchSTNTimeTableByIDService']['row'])
        all_data_frames.append(df)

# 모든 데이터프레임을 하나로 합치기
all_df = pd.concat(all_data_frames, ignore_index=True)

# %%
all_df.head(50)
# Out:
#    LINE_NUM FR_CODE STATION_CD STATION_NM TRAIN_NO ARRIVETIME  LEFTTIME  \
# 0      02호선   211-1       0244         용답     1502   05:35:30  05:36:00
# 1      02호선   211-1       0244         용답     1504   05:52:30  05:53:00
# 2      02호선   211-1       0244         용답     1506   06:07:30  06:08:00
# 3      02호선   211-1       0244         용답     1508   06:22:30  06:23:00
# 4      02호선   211-1       0244         용답     1510   06:38:30  06:39:00
# 5      02호선   211-1       0244         용답     1512   06:50:30  06:51:00
# 6      02호선   211-1       0244         용답     1514   07:00:30  07:01:00
# 7      02호선   211-1       0244         용답     1516   07:11:30  07:12:00
# 8      02호선   211-1       0244         용답     1518   07:21:30  07:22:00
# 9      02호선   211-1       0244         용답     1520   07:28:30  07:29:00
# 10     02호선   211-1       0244         용답     1522   07:35:30  07:36:00
# 11     02호선   211-1       0244         용답     1524   07:42:30  07:43:00
# 12     02호선   211-1       0244         용답     1526   07:51:30  07:52:00
# 13     02호선   211-1       0244         용답     1528   07:58:30  07:59:00
# 14     02호선   211-1       0244         용답     1530   08:05:30  08:06:00
# 15     02호선   211-1       0244         용답     1532   08:12:30  08:13:00
# 16     02호선   211-1       0244         용답     1534   08:21:30  08:22:00
# 17     02호선   211-1       0244         용답     1536   08:28:30  08:29:00
# 18     02호선   211-1       0244         용답     1538   08:37:30  08:38:00
# 19     02호선   211-1       0244         용답     1540   08:46:30  08:47:00
# 20     02호선   211-1       0244         용답     1542   08:59:30  09:00:00
# 21     02호선   211-1       0244         용답     1544   09:08:30  09:09:00
# 22     02호선   211-1       0244         용답     1546   09:18:30  09:19:00
# 23     02호선   211-1       0244         용답     1548   09:28:30  09:29:00
# 24     02호선   211-1       0244         용답     1550   09:38:30  09:39:00
# 25     02호선   211-1       0244         용답     1552   09:51:30  09:52:00
# 26     02호선   211-1       0244         용답     1554   10:01:30  10:02:00
# 27     02호선   211-1       0244         용답     1556   10:11:30  10:12:00
# 28     02호선   211-1       0244         용답     1558   10:20:30  10:21:00
# 29     02호선   211-1       0244         용답     1560   10:32:30  10:33:00
# 30     02호선   211-1       0244         용답     1562   10:42:30  10:43:00
# 31     02호선   211-1       0244         용답     1564   10:52:30  10:53:00
# 32     02호선   211-1       0244         용답     1566   11:02:30  11:03:00
# 33     02호선   211-1       0244         용답     1568   11:13:30  11:14:00
# 34     02호선   211-1       0244         용답     1570   11:23:30  11:24:00
# 35     02호선   211-1       0244         용답     1572   11:33:30  11:34:00
# 36     02호선   211-1       0244         용답     1574   11:43:30  11:44:00
# 37     02호선   211-1       0244         용답     1576   11:54:30  11:55:00
# 38     02호선   211-1       0244         용답     1578   12:04:30  12:05:00
# 39     02호선   211-1       0244         용답     1580   12:14:30  12:15:00
# 40     02호선   211-1       0244         용답     1582   12:24:30  12:25:00
# 41     02호선   211-1       0244         용답     1584   12:35:30  12:36:00
# 42     02호선   211-1       0244         용답     1586   12:45:30  12:46:00
# 43     02호선   211-1       0244         용답     1588   12:55:30  12:56:00
# 44     02호선   211-1       0244         용답     1590   13:05:30  13:06:00
# 45     02호선   211-1       0244         용답     1592   13:16:30  13:17:00
# 46     02호선   211-1       0244         용답     1594   13:26:30  13:27:00
# 47     02호선   211-1       0244         용답     1596   13:36:30  13:37:00
# 48     02호선   211-1       0244         용답     1598   13:46:30  13:47:00
# 49     02호선   211-1       0244         용답     1600   13:57:30  13:58:00
#
#    ORIGINSTATION DESTSTATION SUBWAYSNAME SUBWAYENAME WEEK_TAG INOUT_TAG  \
# 0           0246        0211         신설동          성수        1         1
# 1           0246        0211         신설동          성수        1         1
# 2           0246        0211         신설동          성수        1         1
# 3           0246        0211         신설동          성수        1         1
# 4           0246        0211         신설동          성수        1         1
# 5           0246        0211         신설동          성수        1         1
# 6           0246        0211         신설동          성수        1         1
# 7           0246        0211         신설동          성수        1         1
# 8           0246        0211         신설동          성수        1         1
# 9           0246        0211         신설동          성수        1         1
# 10          0246        0211         신설동          성수        1         1
# 11          0246        0211         신설동          성수        1         1
# 12          0246        0211         신설동          성수        1         1
# 13          0246        0211         신설동          성수        1         1
# 14          0246        0211         신설동          성수        1         1
# 15          0246        0211         신설동          성수        1         1
# 16          0246        0211         신설동          성수        1         1
# 17          0246        0211         신설동          성수        1         1
# 18          0246        0211         신설동          성수        1         1
# 19          0246        0211         신설동          성수        1         1
# 20          0246        0211         신설동          성수        1         1
# 21          0246        0211         신설동          성수        1         1
# 22          0246        0211         신설동          성수        1         1
# 23          0246        0211         신설동          성수        1         1
# 24          0246        0211         신설동          성수        1         1
# 25          0246        0211         신설동          성수        1         1
# 26          0246        0211         신설동          성수        1         1
# 27          0246        0211         신설동          성수        1         1
# 28          0246        0211         신설동          성수        1         1
# 29          0246        0211         신설동          성수        1         1
# 30          0246        0211         신설동          성수        1         1
# 31          0246        0211         신설동          성수        1         1
# 32          0246        0211         신설동          성수        1         1
# 33          0246        0211         신설동          성수        1         1
# 34          0246        0211         신설동          성수        1         1
# 35          0246        0211         신설동          성수        1         1
# 36          0246        0211         신설동          성수        1         1
# 37          0246        0211         신설동          성수        1         1
# 38          0246        0211         신설동          성수        1         1
# 39          0246        0211         신설동          성수        1         1
# 40          0246        0211         신설동          성수        1         1
# 41          0246        0211         신설동          성수        1         1
# 42          0246        0211         신설동          성수        1         1
# 43          0246        0211         신설동          성수        1         1
# 44          0246        0211         신설동          성수        1         1
# 45          0246        0211         신설동          성수        1         1
# 46          0246        0211         신설동          성수        1         1
# 47          0246        0211         신설동          성수        1         1
# 48          0246        0211         신설동          성수        1         1
# 49          0246        0211         신설동          성수        1         1
#
#    FL_FLAG DESTSTATION2 EXPRESS_YN BRANCH_LINE
# 0                                G
# 1                                G
# 2                                G
# 3                                G
# 4                                G
# 5                                G
# 6                                G
# 7                                G
# 8                                G
# 9                                G
# 10                               G
# 11                               G
# 12                               G
# 13                               G
# 14                               G
# 15                               G
# 16                               G
# 17                               G
# 18                               G
# 19                               G
# 20                               G
# 21                               G
# 22                               G
# 23                               G
# 24                               G
# 25                               G
# 26                               G
# 27                               G
# 28                               G
# 29                               G
# 30                               G
# 31                               G
# 32                               G
# 33                               G
# 34                               G
# 35                               G
# 36                               G
# 37                               G
# 38                               G
# 39                               G
# 40                               G
# 41                               G
# 42                               G
# 43                               G
# 44                               G
# 45                               G
# 46                               G
# 47                               G
# 48                               G
# 49                               G

# %%
all_df.LINE_NUM.value_counts()
# Out:
# 01호선    81653
# 02호선    61845
# 05호선    49965
# 07호선    49441
# 04호선    47846
# 03호선    42793
# 09호선    33286
# 06호선    30501
# 08호선    14197
# Name: LINE_NUM, dtype: int64

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411527 entries, 0 to 411526
# Data columns (total 17 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   LINE_NUM       411527 non-null  object
#  1   FR_CODE        411527 non-null  object
#  2   STATION_CD     411527 non-null  object
#  3   STATION_NM     411527 non-null  object
#  4   TRAIN_NO       411527 non-null  object
#  5   ARRIVETIME     411527 non-null  object
#  6   LEFTTIME       411527 non-null  object
#  7   ORIGINSTATION  411527 non-null  object
#  8   DESTSTATION    411527 non-null  object
#  9   SUBWAYSNAME    411527 non-null  object
#  10  SUBWAYENAME    411527 non-null  object
#  11  WEEK_TAG       411527 non-null  object
#  12  INOUT_TAG      411527 non-null  object
#  13  FL_FLAG        411527 non-null  object
#  14  DESTSTATION2   411527 non-null  object
#  15  EXPRESS_YN     411527 non-null  object
#  16  BRANCH_LINE    411527 non-null  object
# dtypes: object(17)
# memory usage: 53.4+ MB

# %%
# 요일과 상하행 숫자를 글자로 매핑하는 딕셔너리 생성
week_mapping = {
    '1': '평일',
    '2': '토요일',
    '3': '휴일/일요일'
}

inout_mapping = {
    '1': '상행',
    '2': '하행'
}

# %%
all_df.to_csv('지하철 열차시간표.csv')

# %% [markdown]
# ### 시간대별 지하철 수 계산 및 새로운 데이터프레임 처리

# %%
unique_stations = all_df['STATION_CD'].unique()
unique_lines = all_df['LINE_NUM'].unique()
unique_week_tags = all_df['WEEK_TAG'].unique()
unique_inout_tags = all_df['INOUT_TAG'].unique()

# 필요한 시간대 컬럼 생성
time_columns = [f'{i:02d}시~{i+1:02d}시' for i in range(5, 25)]

# 결과 데이터프레임 초기화
result_df = pd.DataFrame(columns=['STATION_CD', 'STATION_NM', 'LINE_NUM', '요일', '상하행'] + time_columns)

# 각 역별로 데이터 처리
for station_cd in unique_stations:
    station_name = all_df[all_df['STATION_CD'] == station_cd]['STATION_NM'].iloc[0]
    for line_num in unique_lines:
        for week_tag in unique_week_tags:
            for inout_tag in unique_inout_tags:
                filtered_df = all_df[(all_df['STATION_CD'] == station_cd) &
                                     (all_df['LINE_NUM'] == line_num) &
                                     (all_df['WEEK_TAG'] == week_tag) &
                                     (all_df['INOUT_TAG'] == inout_tag)]

                # 시간대별 열차 수를 저장할 리스트 초기화
                train_counts = [0] * len(time_columns)

                for index, row in filtered_df.iterrows():
                    # hh:mm:ss 중 h만 가져오기
                    arr_time = int(row['ARRIVETIME'].split(':')[0])
                    # 첫 차: 5시 -> 0 index 부터 train_counts 에 저장
                    if 5 <= arr_time < 25:
                        train_counts[arr_time - 5] += 1

                # 모든 시간대가 0인 행은 추가하지 않음
                if all(count == 0 for count in train_counts):
                    continue

                # 결과 데이터프레임에 행 추가
                temp_df = pd.DataFrame({
                    'STATION_CD': [station_cd],
                    'STATION_NM': [station_name],
                    'LINE_NUM': [line_num],
                    '요일': [week_mapping[str(week_tag)]],
                    '상하행': [inout_mapping[str(inout_tag)]],
                    **{time_col: count for time_col, count in zip(time_columns, train_counts)}})

                result_df = pd.concat([result_df, temp_df], ignore_index=True)

# %%
# 결과 출력
result_df
# Out:
#      STATION_CD STATION_NM LINE_NUM      요일 상하행 05시~06시 06시~07시 07시~08시  \
# 0          0244         용답     02호선      평일  상행       2       4       8
# 1          0244         용답     02호선      평일  하행       2       4       7
# 2          0244         용답     02호선     토요일  상행       2       4       5
# 3          0244         용답     02호선     토요일  하행       2       4       5
# 4          0244         용답     02호선  휴일/일요일  상행       2       4       5
# ...         ...        ...      ...     ...  ..     ...     ...     ...
# 2611       0202      을지로입구     02호선      평일  하행       2      10      12
# 2612       0202      을지로입구     02호선     토요일  상행       3      10      11
# 2613       0202      을지로입구     02호선     토요일  하행       2      10      10
# 2614       0202      을지로입구     02호선  휴일/일요일  상행       3      10      11
# 2615       0202      을지로입구     02호선  휴일/일요일  하행       2      10      10
#
#      08시~09시 09시~10시  ... 15시~16시 16시~17시 17시~18시 18시~19시 19시~20시 20시~21시  \
# 0          7       5  ...       5       6       6       7       7       6
# 1          8       5  ...       5       6       6       7       7       5
# 2          6       6  ...       6       6       6       6       6       5
# 3          6       6  ...       6       6       6       6       5       6
# 4          6       6  ...       6       6       6       6       6       5
# ...      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 2611      20      20  ...      11      14      15      16      16      10
# 2612      11      11  ...      11      11      12      11      11      11
# 2613      10      11  ...      11      12      12      11      11      10
# 2614      11      11  ...      11      11      12      11      11      11
# 2615      10      11  ...      11      12      12      11      11      10
#
#      21시~22시 22시~23시 23시~24시 24시~25시
# 0          5       6       5       4
# 1          6       6       5       4
# 2          6       5       6       0
# 3          6       5       6       0
# 4          6       5       6       0
# ...      ...     ...     ...     ...
# 2611      12       7       9       5
# 2612       9       8       5       1
# 2613      10       9       6       1
# 2614       9       8       5       1
# 2615      10       9       6       1
#
# [2616 rows x 25 columns]

# %%
result_df.to_csv('지하철 열차시간표(요일, 상하행별).csv')

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2616 entries, 0 to 2615
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATION_CD  2616 non-null   object
#  1   STATION_NM  2616 non-null   object
#  2   LINE_NUM    2616 non-null   object
#  3   요일          2616 non-null   object
#  4   상하행         2616 non-null   object
#  5   05시~06시     2616 non-null   object
#  6   06시~07시     2616 non-null   object
#  7   07시~08시     2616 non-null   object
#  8   08시~09시     2616 non-null   object
#  9   09시~10시     2616 non-null   object
#  10  10시~11시     2616 non-null   object
#  11  11시~12시     2616 non-null   object
#  12  12시~13시     2616 non-null   object
#  13  13시~14시     2616 non-null   object
#  14  14시~15시     2616 non-null   object
#  15  15시~16시     2616 non-null   object
#  16  16시~17시     2616 non-null   object
#  17  17시~18시     2616 non-null   object
#  18  18시~19시     2616 non-null   object
#  19  19시~20시     2616 non-null   object
#  20  20시~21시     2616 non-null   object
#  21  21시~22시     2616 non-null   object
#  22  22시~23시     2616 non-null   object
#  23  23시~24시     2616 non-null   object
#  24  24시~25시     2616 non-null   object
# dtypes: object(25)
# memory usage: 511.1+ KB

# %%
result_df[time_columns].value_counts()
# Out:
# 05시~06시  06시~07시  07시~08시  08시~09시  09시~10시  10시~11시  11시~12시  12시~13시  13시~14시  14시~15시  15시~16시  16시~17시  17시~18시  18시~19시  19시~20시  20시~21시  21시~22시  22시~23시  23시~24시  24시~25시
# 2        4        6        6        6        6        6        6        6        6        6        6        6        6        6        6        6        5        4        0          6
# 3        9        10       9        10       10       9        10       11       10       10       10       10       10       10       10       9        8        5        0          4
# 2        5        8        9        10       9        9        9        9        10       9        9        9        9        10       9        9        8        7        1          4
#          7        7        7        7        7        7        7        7        7        7        7        7        7        8        6        7        5        5        1          4
#          5        8        9        9        9        9        10       9        9        9        9        10       9        9        9        9        9        7        1          4
#                                                                                                                                                                                      ..
# 1        13       16       16       13       13       11       11       10       11       11       11       15       17       16       15       12       10       7        3          1
#                            15       14       13       11       11       9        12       11       10       15       17       16       15       13       10       7        3          1
#          12       16       15       15       12       11       11       10       11       11       11       15       17       16       15       13       9        8        3          1
#                   15       16       14       13       11       11       10       11       11       11       14       17       16       16       12       10       8        3          1
# 9        22       23       28       20       19       20       13       17       16       17       21       24       25       24       20       19       16       9        0          1
# Length: 1699, dtype: int64

# %%
# 기초 통계량 확인
stats = result_df[time_columns].describe()
stats
# Out:
#         05시~06시  06시~07시  07시~08시  08시~09시  09시~10시  10시~11시  11시~12시  \
# count      2616     2616     2616     2616     2616     2616     2616
# unique       10       21       24       28       25       22       20
# top           2        7       10        9       10       10        9
# freq       1007      411      423      381      356      415      407
#
#         12시~13시  13시~14시  14시~15시  15시~16시  16시~17시  17시~18시  18시~19시  \
# count      2616     2616     2616     2616     2616     2616     2616
# unique       19       19       19       20       21       24       25
# top          10       10        7        7        7        7        7
# freq        386      356      415      416      389      403      383
#
#         19시~20시  20시~21시  21시~22시  22시~23시  23시~24시  24시~25시
# count      2616     2616     2616     2616     2616     2616
# unique       24       23       22       18       16       13
# top           9        9        9        8        5        0
# freq        358      428      499      490      622     1203

# %% [markdown]
# ### 호선별로 데이터 분할 및 csv 파일 저장

# %%
import os

# 분할된 데이터를 저장할 디렉토리 경로 설정
output_dir = '호선별_시간별_지하철수데이터/'

# 디렉토리가 존재하지 않으면 생성
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# LINE_NUM 값에 따라 데이터 분할 및 저장
line_nums = ['01호선', '02호선', '03호선', '04호선', '05호선', '06호선', '07호선', '08호선']

for line_num in line_nums:
    # 조건에 맞는 데이터 추출
    subset_df = result_df[result_df['LINE_NUM'] == line_num]

    # CSV 파일로 저장 (파일명은 호선별로 구분)
    file_name = f'{line_num}.csv'
    subset_df.to_csv(output_dir + file_name, index=False)

print("데이터 분할 및 저장 완료.")
# Out:
# 데이터 분할 및 저장 완료.

# %%
line_01 = pd.read_csv('호선별_시간별_지하철수데이터/01호선.csv')
line_01
# Out:
#      STATION_CD STATION_NM LINE_NUM      요일 상하행  05시~06시  06시~07시  07시~08시  \
# 0          1407       온양온천     01호선      평일  상행        2        3        2
# 1          1407       온양온천     01호선      평일  하행        1        3        2
# 2          1407       온양온천     01호선     토요일  상행        2        1        2
# 3          1407       온양온천     01호선     토요일  하행        0        2        2
# 4          1407       온양온천     01호선  휴일/일요일  상행        2        1        2
# ..          ...        ...      ...     ...  ..      ...      ...      ...
# 574         159        동묘앞     01호선      평일  하행        6       10       15
# 575         159        동묘앞     01호선     토요일  상행        4       10       12
# 576         159        동묘앞     01호선     토요일  하행        5        9       12
# 577         159        동묘앞     01호선  휴일/일요일  상행        4       10       12
# 578         159        동묘앞     01호선  휴일/일요일  하행        5        9       12
#
#      08시~09시  09시~10시  ...  15시~16시  16시~17시  17시~18시  18시~19시  19시~20시  \
# 0          2        2  ...        2        2        1        3        2
# 1          2        2  ...        1        2        2        2        3
# 2          2        1  ...        2        1        2        2        3
# 3          1        2  ...        2        2        2        2        2
# 4          2        1  ...        2        1        2        2        3
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 574       17       13  ...       12       12       14       14       14
# 575       13       13  ...       13       14       13       14       14
# 576       12       12  ...       13       15       12       13       11
# 577       13       13  ...       13       14       13       14       14
# 578       12       12  ...       13       15       12       13       11
#
#      20시~21시  21시~22시  22시~23시  23시~24시  24시~25시
# 0          2        2        3        2        0
# 1          3        2        2        2        1
# 2          1        2        3        2        0
# 3          2        3        2        2        0
# 4          1        2        3        2        0
# ..       ...      ...      ...      ...      ...
# 574       14       12       12        7        2
# 575       14       12       12        9        2
# 576       13       12       11        8        0
# 577       14       12       12        9        2
# 578       13       12       11        8        0
#
# [579 rows x 25 columns]

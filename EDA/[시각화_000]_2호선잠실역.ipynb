# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd

wet_23 = pd.read_csv("[기상_102]_날짜_요일_기상조건_2023.csv")
sub_23 = pd.read_csv("[지하철_100]호선별역별_승하차정보_2023.csv")

# %%
wet_23
# Out:
#         연  월   일 요일   기상조건  평균기온(℃)  최저기온(℃)  최고기온(℃)  강수량(mm)
# 0    2023  1   1  일     맑음     -0.2     -4.3      3.8      0.0
# 1    2023  1   2  월     맑음     -4.5     -7.4     -0.4      0.0
# 2    2023  1   3  화     맑음     -5.0     -9.0      0.6      0.0
# 3    2023  1   4  수     맑음     -1.8     -5.7      3.3      0.0
# 4    2023  1   5  목     맑음     -1.6     -5.6      3.6      0.0
# ..    ... ..  .. ..    ...      ...      ...      ...      ...
# 232  2023  8  21  월  폭염/한파     29.5     26.0     33.6      0.0
# 233  2023  8  22  화   약한눈비     27.6     25.8     32.2     42.6
# 234  2023  8  23  수   약한눈비     24.8     23.2     27.2     41.8
# 235  2023  8  24  목   약한눈비     25.1     22.3     27.8      5.2
# 236  2023  8  25  금     맑음     26.5     24.0     30.0      0.0
#
# [237 rows x 9 columns]

# %%
sub_23.head(2)
# Out:
#          사용일자     연  월  일 요일  호선명 지하철역   승차총승객수   하차총승객수
# 0  2023-01-01  2023  1  1  일  1호선  서울역  31924.0  26931.0
# 1  2023-01-01  2023  1  1  일  1호선   시청   9282.0   8253.0

# %%
sub_23.sort_values(by='승차총승객수', ascending=False).head(20)
# Out:
#              사용일자     연  월   일 요일  호선명      지하철역    승차총승객수    하차총승객수
# 28051  2023-04-01  2023  4   1  토  2호선  잠실(송파구청)  125862.0  123306.0
# 27740  2023-03-31  2023  3  31  금  2호선  잠실(송파구청)  108416.0  109576.0
# 62660  2023-07-21  2023  7  21  금  2호선        강남   98353.0   96888.0
# 58300  2023-07-07  2023  7   7  금  2호선        강남   97647.0   95762.0
# 28363  2023-04-02  2023  4   2  일  2호선  잠실(송파구청)   97584.0   92350.0
# 10297  2023-02-03  2023  2   3  금  2호선        강남   97528.0   95675.0
# 62348  2023-07-20  2023  7  20  목  2호선        강남   97093.0   92722.0
# 16838  2023-02-24  2023  2  24  금  2호선        강남   96989.0   95165.0
# 36473  2023-04-28  2023  4  28  금  2호선        강남   96765.0   94078.0
# 12477  2023-02-10  2023  2  10  금  2호선        강남   96554.0   94821.0
# 40842  2023-05-12  2023  5  12  금  2호선        강남   96529.0   94585.0
# 14658  2023-02-17  2023  2  17  금  2호선        강남   96430.0   94802.0
# 8120   2023-01-27  2023  1  27  금  2호선        강남   96333.0   94974.0
# ...

# %% [markdown]
# ### 2호선 잠실역 컬럼 추출

# %%
sub_23_js = sub_23[(sub_23['지하철역'] == '잠실(송파구청)') & (sub_23['호선명'] == '2호선')].reset_index()
sub_23_js
# Out:
#      index        사용일자     연  월   일 요일  호선명      지하철역   승차총승객수   하차총승객수
# 0       25  2023-01-01  2023  1   1  일  2호선  잠실(송파구청)  41697.0  38173.0
# 1      337  2023-01-02  2023  1   2  월  2호선  잠실(송파구청)  71411.0  71280.0
# 2      647  2023-01-03  2023  1   3  화  2호선  잠실(송파구청)  76191.0  75392.0
# 3      959  2023-01-04  2023  1   4  수  2호선  잠실(송파구청)  77538.0  76787.0
# 4     1270  2023-01-05  2023  1   5  목  2호선  잠실(송파구청)  79043.0  78243.0
# ..     ...         ...   ... ..  .. ..  ...       ...      ...      ...
# 230  71687  2023-08-19  2023  8  19  토  2호선  잠실(송파구청)  71469.0  69966.0
# 231  71999  2023-08-20  2023  8  20  일  2호선  잠실(송파구청)  53300.0  50921.0
# 232  72310  2023-08-21  2023  8  21  월  2호선  잠실(송파구청)  73392.0  73405.0
# 233  72621  2023-08-22  2023  8  22  화  2호선  잠실(송파구청)  76637.0  76296.0
# 234  72934  2023-08-23  2023  8  23  수  2호선  잠실(송파구청)  74536.0  74263.0
#
# [235 rows x 10 columns]

# %% [markdown]
# ### 기상조건 추가
# - wet_23에서 기상조건 컬럼 추출

# %%
wet_23_con = wet_23['기상조건']
wet_23_con
# Out:
# 0         맑음
# 1         맑음
# 2         맑음
# 3         맑음
# 4         맑음
#        ...
# 232    폭염/한파
# 233     약한눈비
# 234     약한눈비
# 235     약한눈비
# 236       맑음
# Name: 기상조건, Length: 237, dtype: object

# %% [markdown]
# - 데이터프레임 합치기

# %%
jsil_2 = pd.concat([sub_23_js, wet_23_con], axis=1)
jsil_2.drop(columns='index', axis=1)
jsil_2.dropna(inplace=True)
jsil_2
# Out:
#        index        사용일자       연    월     일 요일  호선명      지하철역   승차총승객수  \
# 0       25.0  2023-01-01  2023.0  1.0   1.0  일  2호선  잠실(송파구청)  41697.0
# 1      337.0  2023-01-02  2023.0  1.0   2.0  월  2호선  잠실(송파구청)  71411.0
# 2      647.0  2023-01-03  2023.0  1.0   3.0  화  2호선  잠실(송파구청)  76191.0
# 3      959.0  2023-01-04  2023.0  1.0   4.0  수  2호선  잠실(송파구청)  77538.0
# 4     1270.0  2023-01-05  2023.0  1.0   5.0  목  2호선  잠실(송파구청)  79043.0
# ..       ...         ...     ...  ...   ... ..  ...       ...      ...
# 230  71687.0  2023-08-19  2023.0  8.0  19.0  토  2호선  잠실(송파구청)  71469.0
# 231  71999.0  2023-08-20  2023.0  8.0  20.0  일  2호선  잠실(송파구청)  53300.0
# 232  72310.0  2023-08-21  2023.0  8.0  21.0  월  2호선  잠실(송파구청)  73392.0
# 233  72621.0  2023-08-22  2023.0  8.0  22.0  화  2호선  잠실(송파구청)  76637.0
# 234  72934.0  2023-08-23  2023.0  8.0  23.0  수  2호선  잠실(송파구청)  74536.0
#
#       하차총승객수   기상조건
# 0    38173.0     맑음
# 1    71280.0     맑음
# 2    75392.0     맑음
# 3    76787.0     맑음
# ...

# %% [markdown]
# # EDA

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# - 한글 폰트 설정

# %%
import platform
print(platform.system())
# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'
# Out:
# Windows

# %% [markdown]
# ## 2호선 잠실역 관련

# %% [markdown]
# ### 전체 승차총승객수 분포

# %%
sns.displot(jsil_2['승차총승객수'],
           color = "#FC7F77")

plt.show()

# %% [markdown]
# ### 기상조건별 2호선 잠실역 승차총승객수

# %%
jsil_2.groupby(['기상조건'])['승차총승객수'].mean()
# Out:
# 기상조건
# 맑음       76051.540541
# 약한눈비     72706.378788
# 폭염/한파    74089.285714
# Name: 승차총승객수, dtype: float64

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x = '기상조건',
            y = '승차총승객수',
            data = jsil_2, 
            palette="Set2")
plt.show()

# %% [markdown]
# ### 월별 2호선 잠실역 승차총승객수

# %%
jsil_2.groupby(['월'])['승차총승객수'].mean()
# Out:
# 월
# 1.0    68783.193548
# 2.0    78779.500000
# 3.0    74810.161290
# 4.0    79472.900000
# 5.0    74806.258065
# 6.0    74143.933333
# 7.0    75455.903226
# 8.0    73316.173913
# Name: 승차총승객수, dtype: float64

# %%
jsil_2 = jsil_2.astype({'월' : 'int'})
plt.figure(figsize = (12, 6))
sns.barplot(x = '월',
            y = '승차총승객수',
            data = jsil_2, 
            palette="Set2")
plt.show()

# %% [markdown]
# ### 기상조건별 빈도수

# %%
plt.figure(figsize = (9, 6))
plt.xticks(rotation = 10)
sns.countplot(x = '기상조건',
              data = jsil_2, 
            palette="Set2")
plt.show()

# %% [markdown]
# ### 요일별 승차총승객수

# %%
jsil_2.groupby(['요일'])['승차총승객수'].mean()
# Out:
# 요일
# 금    83584.454545
# 목    80272.272727
# 수    78277.117647
# 월    74244.941176
# 일    56776.147059
# 토    75448.545455
# 화    76379.735294
# Name: 승차총승객수, dtype: float64

# %%
jsil_2 = jsil_2.astype({'월' : 'int'})
plt.figure(figsize = (12, 6))
sns.barplot(x = '요일',
            y = '승차총승객수',
            data = jsil_2, 
            palette="Set2"
           )
plt.show()

# %%
data = {
    '요일': ['금', '목', '수', '월', '일', '토', '화'],
    '승차총승객수평균': [83584.454545, 80272.272727, 78277.117647, 74244.941176, 56776.147059, 75448.545455, 76379.735294]
}

df = pd.DataFrame(data)
df
weekend_avg = (56776.147059 + 75448.545455) / 2
weekday_avg = (83584.454545 + 80272.272727 + 78277.117647 + 74244.941176 + 76379.735294) / 5

df_mean = {'when' : ['주중', '주말'], '승차총승객수평균' : [weekday_avg, weekend_avg]}
result = pd.DataFrame(df_mean)
print(result)
# Out:
#   when      승차총승객수평균
# 0   주중  78551.704278
# 1   주말  66112.346257

# %%
# result = jsil_2.astype({'월' : 'int'})
plt.figure(figsize = (12, 6))
sns.barplot(x = 'when',
            y = '승차총승객수평균',
            data = result, 
            palette="Set2")
plt.show()

# %% [markdown]
# ### 공휴일
# - 1월1일	20230101
# 설날	20230121
# 설날	20230122
# 설날	20230123
# 대체공휴일	20230124
# 삼일절	20230301
# 어린이날	20230505
# 부처님오신날	20230527
# 대체공휴일	20230529
# 현충일	20230606
# 광복절	20230815
# 추석	20230928
# 추석	20230929
# 추석	20230930
# 개천절	20231003
# 한글날	20231009
# 기독탄신일	20231225

# %%
sub_23_js
# Out:
#      index        사용일자     연  월   일 요일  호선명      지하철역   승차총승객수   하차총승객수
# 0       25  2023-01-01  2023  1   1  일  2호선  잠실(송파구청)  41697.0  38173.0
# 1      337  2023-01-02  2023  1   2  월  2호선  잠실(송파구청)  71411.0  71280.0
# 2      647  2023-01-03  2023  1   3  화  2호선  잠실(송파구청)  76191.0  75392.0
# 3      959  2023-01-04  2023  1   4  수  2호선  잠실(송파구청)  77538.0  76787.0
# 4     1270  2023-01-05  2023  1   5  목  2호선  잠실(송파구청)  79043.0  78243.0
# ..     ...         ...   ... ..  .. ..  ...       ...      ...      ...
# 230  71687  2023-08-19  2023  8  19  토  2호선  잠실(송파구청)  71469.0  69966.0
# 231  71999  2023-08-20  2023  8  20  일  2호선  잠실(송파구청)  53300.0  50921.0
# 232  72310  2023-08-21  2023  8  21  월  2호선  잠실(송파구청)  73392.0  73405.0
# 233  72621  2023-08-22  2023  8  22  화  2호선  잠실(송파구청)  76637.0  76296.0
# 234  72934  2023-08-23  2023  8  23  수  2호선  잠실(송파구청)  74536.0  74263.0
#
# [235 rows x 10 columns]

# %% [markdown]
# ### 공휴일 - 1월
# - 1월달 승객수 비교

# %%
sub_23_js_1 = sub_23_js[sub_23_js['월'] == 1].reset_index()
sub_23_js_1
# Out:
#     level_0  index        사용일자     연  월   일 요일  호선명      지하철역   승차총승객수  \
# 0         0     25  2023-01-01  2023  1   1  일  2호선  잠실(송파구청)  41697.0
# 1         1    337  2023-01-02  2023  1   2  월  2호선  잠실(송파구청)  71411.0
# 2         2    647  2023-01-03  2023  1   3  화  2호선  잠실(송파구청)  76191.0
# 3         3    959  2023-01-04  2023  1   4  수  2호선  잠실(송파구청)  77538.0
# 4         4   1270  2023-01-05  2023  1   5  목  2호선  잠실(송파구청)  79043.0
# 5         5   1581  2023-01-06  2023  1   6  금  2호선  잠실(송파구청)  82403.0
# 6         6   1892  2023-01-07  2023  1   7  토  2호선  잠실(송파구청)  73142.0
# 7         7   2203  2023-01-08  2023  1   8  일  2호선  잠실(송파구청)  54259.0
# 8         8   2514  2023-01-09  2023  1   9  월  2호선  잠실(송파구청)  74423.0
# 9         9   2825  2023-01-10  2023  1  10  화  2호선  잠실(송파구청)  79055.0
# 10       10   3136  2023-01-11  2023  1  11  수  2호선  잠실(송파구청)  81384.0
# 11       11   3446  2023-01-12  2023  1  12  목  2호선  잠실(송파구청)  81607.0
# ...

# %%
sns.displot(sub_23_js_1['승차총승객수'],
           color = "#FC7F77")

plt.show()

# %% [markdown]
# - 1월 날짜별 승차총승객수
#   - 1월1일 20230101 설날 20230121 설날 20230122 설날 20230123 대체공휴일 20230124
#   - 승객수가 상대적으로 적다.
#   - 8, 15, 29일은 일요일.

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x = '일',
            y = '승차총승객수',
            data = sub_23_js_1, 
            palette="Set2"
           )
plt.show()

# %% [markdown]
# - 1월 중 요일별 승차총승객수

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x = '요일',
            y = '승차총승객수',
            data = sub_23_js_1, 
            palette="Set2"
           )
plt.show()

# %% [markdown]
# - 1월 기상조건별 승차총승객수

# %%
sub_23_js_1 = pd.concat([sub_23_js_1, wet_23_con], axis=1)
sub_23_js_1.drop(columns='index', axis=1)
sub_23_js_1.dropna(inplace=True)
sub_23_js_1
# Out:
#     level_0   index        사용일자       연    월     일 요일  호선명      지하철역   승차총승객수  \
# 0       0.0    25.0  2023-01-01  2023.0  1.0   1.0  일  2호선  잠실(송파구청)  41697.0
# 1       1.0   337.0  2023-01-02  2023.0  1.0   2.0  월  2호선  잠실(송파구청)  71411.0
# 2       2.0   647.0  2023-01-03  2023.0  1.0   3.0  화  2호선  잠실(송파구청)  76191.0
# 3       3.0   959.0  2023-01-04  2023.0  1.0   4.0  수  2호선  잠실(송파구청)  77538.0
# 4       4.0  1270.0  2023-01-05  2023.0  1.0   5.0  목  2호선  잠실(송파구청)  79043.0
# 5       5.0  1581.0  2023-01-06  2023.0  1.0   6.0  금  2호선  잠실(송파구청)  82403.0
# 6       6.0  1892.0  2023-01-07  2023.0  1.0   7.0  토  2호선  잠실(송파구청)  73142.0
# 7       7.0  2203.0  2023-01-08  2023.0  1.0   8.0  일  2호선  잠실(송파구청)  54259.0
# 8       8.0  2514.0  2023-01-09  2023.0  1.0   9.0  월  2호선  잠실(송파구청)  74423.0
# 9       9.0  2825.0  2023-01-10  2023.0  1.0  10.0  화  2호선  잠실(송파구청)  79055.0
# 10     10.0  3136.0  2023-01-11  2023.0  1.0  11.0  수  2호선  잠실(송파구청)  81384.0
# ...

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x = '기상조건',
            y = '승차총승객수',
            data = sub_23_js_1, 
            palette="Set2"
           )
plt.show()
